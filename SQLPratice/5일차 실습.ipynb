# %%
# !pip install SQLAlchemy==1.4.47
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 28.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: SQLAlchemy
#     Found existing installation: SQLAlchemy 2.0.10
#     Uninstalling SQLAlchemy-2.0.10:
#       Successfully uninstalled SQLAlchemy-2.0.10
# ...

# %%
! kill -9 $(ps -A | grep python | awk '{print $1}')

# %%
# %load_ext sql

# %%
# ID와 PW를 자신의 환경에 맞게 수정

# %% [markdown]
# ## 과제 풀이

# %% [markdown]
# ### 1. 사용자별로 처음 채널과 마지막 채널이 무엇이었는지 찾기
# 1) CTE를 빌딩 블록으로 사용

# %%
# %%sql
#
# WITH FIRST AS (
#   SELECT USERID
#        , TS
#        , CHANNEL
#        , ROW_NUMBER() OVER (PARTITION BY USERID ORDER BY TS) SEQ
#     FROM RAW_DATA.USER_SESSION_CHANNEL A
#     JOIN RAW_DATA.SESSION_TIMESTAMP B
#       ON A.SESSIONID = B.SESSIONID
# ), LAST AS (
#   SELECT USERID
#        , TS
#        , CHANNEL
#        , ROW_NUMBER() OVER (PARTITION BY USERID ORDER BY TS DESC) SEQ
#     FROM RAW_DATA.USER_SESSION_CHANNEL A
#     JOIN RAW_DATA.SESSION_TIMESTAMP B
#       ON A.SESSIONID = B.SESSIONID
# )
# SELECT FIRST.USERID
#      , FIRST.CHANNEL AS FIRST_CHANNEL
#      , LAST.CHANNEL AS LAST_CHANNEL
#   FROM FIRST
#   JOIN LAST
#     ON FIRST.USERID = LAST.USERID
#    AND LAST.SEQ = 1
#  WHERE FIRST.SEQ = 1;
# Out:
#  * postgresql://guest:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 949 rows affected.
# [(27, 'Youtube', 'Instagram'),
#  (29, 'Naver', 'Naver'),
#  (33, 'Google', 'Youtube'),
#  (40, 'Youtube', 'Google'),
#  (44, 'Naver', 'Instagram'),
#  (59, 'Instagram', 'Instagram'),
#  (68, 'Youtube', 'Organic'),
#  (87, 'Youtube', 'Google'),
#  (97, 'Organic', 'Organic'),
#  (113, 'Organic', 'Organic'),
#  (114, 'Instagram', 'Youtube'),
#  (163, 'Google', 'Naver'),
#  (187, 'Organic', 'Youtube'),
#  (191, 'Naver', 'Instagram'),
#  (196, 'Facebook', 'Naver'),
#  (197, 'Naver', 'Youtube'),
#  (210, 'Google', 'Google'),
#  (213, 'Naver', 'Organic'),
#  (216, 'Instagram', 'Naver'),
#  (218, 'Google', 'Youtube'),
#  (223, 'Youtube', 'Facebook'),
#  (225, 'Facebook', 'Naver'),
#  (229, 'Google', 'Facebook'),
#  (231, 'Naver', 'Instagram'),
#  (232, 'Instagram', 'Naver'),
#  (243, 'Youtube', 'Instagram'),
#  (248, 'Naver', 'Instagram'),
#  (251, 'Facebook', 'Google'),
# ...

# %% [markdown]
# ### 2) GROUP BY 방식

# %%
# %%sql
#
# SELECT USERID
#      , MAX(CASE WHEN RN1 = 1 THEN CHANNEL END) LAST_TOUCH
#      , MAX(CASE WHEN RN2 = 1 THEN CHANNEL END) FIRST_TOUCH
#   FROM (
#             SELECT A.USERID
#                 , A.SESSIONID
#                 , A.CHANNEL
#                 , ROW_NUMBER() OVER (PARTITION BY A.USERID ORDER BY B.TS DESC) RN1
#                 , ROW_NUMBER() OVER (PARTITION BY A.USERID ORDER BY B.TS ASC)  RN2
#               FROM RAW_DATA.USER_SESSION_CHANNEL A
#               JOIN RAW_DATA.SESSION_TIMESTAMP B
#                 ON A.SESSIONID = B.SESSIONID
#       )
# GROUP BY 1;
# Out:
#  * postgresql://guest:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 949 rows affected.
# [(27, 'Instagram', 'Youtube'),
#  (29, 'Naver', 'Naver'),
#  (33, 'Youtube', 'Google'),
#  (40, 'Google', 'Youtube'),
#  (44, 'Instagram', 'Naver'),
#  (59, 'Instagram', 'Instagram'),
#  (68, 'Organic', 'Youtube'),
#  (87, 'Google', 'Youtube'),
#  (97, 'Organic', 'Organic'),
#  (113, 'Organic', 'Organic'),
#  (114, 'Youtube', 'Instagram'),
#  (163, 'Naver', 'Google'),
#  (187, 'Youtube', 'Organic'),
#  (191, 'Instagram', 'Naver'),
#  (196, 'Naver', 'Facebook'),
#  (197, 'Youtube', 'Naver'),
#  (210, 'Google', 'Google'),
#  (213, 'Organic', 'Naver'),
#  (216, 'Naver', 'Instagram'),
#  (218, 'Youtube', 'Google'),
#  (223, 'Facebook', 'Youtube'),
#  (225, 'Naver', 'Facebook'),
#  (229, 'Facebook', 'Google'),
#  (231, 'Instagram', 'Naver'),
#  (232, 'Naver', 'Instagram'),
#  (243, 'Instagram', 'Youtube'),
#  (248, 'Instagram', 'Naver'),
#  (251, 'Google', 'Facebook'),
# ...

# %% [markdown]
# ### 3) FIRST_VALUE/LAST_VALUE 사용하기

# %%
# %%sql
#
# SELECT DISTINCT A.USERID
#      , FIRST_VALUE(A.CHANNEL) OVER(PARTITION BY A.USERID
#                                        ORDER BY B.TS
#                                            ROWS
#                                         BETWEEN UNBOUNDED PRECEDING
#                                             AND UNBOUNDED FOLLOWING) AS FIRST_CHANNEL
#      , LAST_VALUE(A.CHANNEL) OVER(PARTITION BY A.USERID
#                                       ORDER BY B.TS
#                                           ROWS
#                                        BETWEEN UNBOUNDED PRECEDING
#                                           AND UNBOUNDED FOLLOWING) AS LAST_CHANNEL
#   FROM RAW_DATA.USER_SESSION_CHANNEL A
#   LEFT JOIN RAW_DATA.SESSION_TIMESTAMP B
#          ON A.SESSIONID = B.SESSIONID ;
# Out:
#  * postgresql://guest:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 949 rows affected.
# [(34, 'Youtube', 'Naver'),
#  (36, 'Naver', 'Youtube'),
#  (69, 'Facebook', 'Instagram'),
#  (112, 'Facebook', 'Youtube'),
#  (173, 'Google', 'Organic'),
#  (181, 'Facebook', 'Instagram'),
#  (184, 'Youtube', 'Youtube'),
#  (193, 'Google', 'Facebook'),
#  (199, 'Naver', 'Instagram'),
#  (203, 'Naver', 'Facebook'),
#  (222, 'Facebook', 'Google'),
#  (227, 'Google', 'Google'),
#  (240, 'Organic', 'Organic'),
#  (250, 'Instagram', 'Facebook'),
#  (254, 'Facebook', 'Facebook'),
#  (256, 'Naver', 'Instagram'),
#  (270, 'Facebook', 'Youtube'),
#  (282, 'Naver', 'Facebook'),
#  (368, 'Organic', 'Youtube'),
#  (371, 'Google', 'Google'),
#  (474, 'Facebook', 'Naver'),
#  (510, 'Naver', 'Facebook'),
#  (511, 'Google', 'Google'),
#  (543, 'Naver', 'Instagram'),
#  (572, 'Organic', 'Naver'),
#  (599, 'Organic', 'Google'),
#  (643, 'Facebook', 'Facebook'),
# ...

# %% [markdown]
# ## 2. Gross Revenue가 가장 큰 UserID 10 개 찾기

# %% [markdown]
# #### 1) GROUP BY 사용하기

# %%
# %%sql
#
#
# SELECT A.USERID
#      , SUM(B.AMOUNT)  GROSS_REVENUE
#   FROM RAW_DATA.USER_SESSION_CHANNEL A
# LEFT JOIN RAW_DATA.SESSION_TRANSACTION B
#     ON A.SESSIONID = B.SESSIONID
# GROUP BY A.USERID
# ORDER BY GROSS_REVENUE DESC
# LIMIT 10;
# Out:
#  * postgresql://guest:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 10 rows affected.
# [(989, 743),
#  (772, 556),
#  (1615, 506),
#  (654, 488),
#  (1651, 463),
#  (973, 438),
#  (262, 422),
#  (1099, 421),
#  (2682, 414),
#  (891, 412)]

# %% [markdown]
# ### 2) SUM OVER 사용하기
#
# - GROUP BY의 경우 USERID 하나에 합산 값이 나오게 되는데 SUM OVER를 사용하게 되면 USERID가 나온 수만큼 동일한 수의 레코드만큼 나오게 된다.
# - 그렇기 때문에 중복을 제거하기 위해 DISTINCT를 사용해야 한다.

# %%
# %%sql
#
# SELECT DISTINCT A.USERID
#      , SUM(AMOUNT) OVER(PARTITION BY A.USERID)
#   FROM RAW_DATA.USER_SESSION_CHANNEL A
#   JOIN RAW_DATA.SESSION_TRANSACTION B
#     ON A.SESSIONID = B.SESSIONID
# ORDER BY 2 DESC
# LIMIT 10;
# Out:
#  * postgresql://guest:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 10 rows affected.
# [(989, 743),
#  (772, 556),
#  (1615, 506),
#  (654, 488),
#  (1651, 463),
#  (973, 438),
#  (262, 422),
#  (1099, 421),
#  (2682, 414),
#  (891, 412)]

# %% [markdown]
# ## 3. raw_data.nps 테이블을 바탕으로 월별 NPS 계산

# %% [markdown]
# ### 1) FROM 절에서 서브 쿼리 사용

# %%
# %%sql
#
# SELECT MONTH
#      , ROUND((PROMOTERS-DETRACTORS)::FLOAT/NULLIF(TOTAL_COUNT, 0)*100, 2) NPS
#   FROM (
#       SELECT LEFT(CREATED_AT, 7) "MONTH"
#            , COUNT(CASE WHEN SCORE >= 9 THEN 1 END)   PROMOTERS
#            , COUNT(CASE WHEN SCORE <= 6 THEN 1 END)   DETRACTORS
#            , COUNT(CASE WHEN SCORE > 6 AND SCORE < 9 THEN 1 END)  PASSIVES
#            , COUNT(1)  TOTAL_COUNT
#         FROM RAW_DATA.NPS
#     GROUP BY 1
#     ORDER BY 1
#   )
# Out:
#  * postgresql://guest:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 12 rows affected.
# [('2019-01', 2.36),
#  ('2019-02', 30.54),
#  ('2019-03', 52.91),
#  ('2019-04', 53.0),
#  ('2019-05', 54.52),
#  ('2019-06', 65.02),
#  ('2019-07', 64.51),
#  ('2019-08', 67.71),
#  ('2019-09', 37.95),
#  ('2019-10', 53.29),
#  ('2019-11', 61.29),
#  ('2019-12', 65.99)]

# %% [markdown]
# ### 2) 하나의 SELECT문에 모든 계산을 넣기

# %%
# %%sql
#
# SELECT LEFT(CREATED_AT, 7) AS "MONTH"
#      , ROUND(SUM(CASE WHEN SCORE >= 9 THEN 1
#                       WHEN SCORE <= 6 THEN -1
#                       END)::FLOAT*100/COUNT(1), 2)     NPS
#   FROM RAW_DATA.NPS
# GROUP BY 1
# ORDER BY 1;
# Out:
#  * postgresql://guest:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 12 rows affected.
# [('2019-01', 2.36),
#  ('2019-02', 30.54),
#  ('2019-03', 52.91),
#  ('2019-04', 53.0),
#  ('2019-05', 54.52),
#  ('2019-06', 65.02),
#  ('2019-07', 64.51),
#  ('2019-08', 67.71),
#  ('2019-09', 37.95),
#  ('2019-10', 53.29),
#  ('2019-11', 61.29),
#  ('2019-12', 65.99)]

# %% [markdown]
# # 트랜잭션 실습

# %% [markdown]
# - GOOGLE COLAB은 기본적으로 AUTOCOMMIT = TRUE으로 세팅이 되어 있다. 이를 PYTHON을 통해 케이스에 따라 나눠 트랜잭션을 적용해 보자.

# %%
# %%sql
#
# DROP TABLE IF EXISTS ADHOC.SONGJIHYE_NAME_GENDER;
#
#
# CREATE TABLE ADHOC.SONGJIHYE_NAME_GENDER (
#   name varchar(32),
#   gender varchar(16)
# );
# INSERT INTO ADHOC.SONGJIHYE_NAME_GENDER VALUES ('Ben', 'Male'), ('Maddie', 'Female');
# Out:
#  * postgresql://guest:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# Done.
# Done.
# 2 rows affected.
# []

# %%
# %%sql
#
# SELECT *
#   FROM ADHOC.SONGJIHYE_NAME_GENDER;
# Out:
#  * postgresql://guest:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 2 rows affected.
# [('Ben', 'Male'), ('Maddie', 'Female')]

# %% [markdown]
# psycopg2를 이용해 redshift와 connection 하여 autocommit 타입에 따라 트랜잭션을 사용해 보자

# %%
import psycopg2

# Redshift connection 함수
def get_Redshift_connection(autocommit):
    host = "learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com"
    redshift_user = "guest"
    redshift_pass = ""
    port = 5439
    dbname = "dev"
    conn = psycopg2.connect("dbname={dbname} user={user} host={host} password={password} port={port}".format(
        dbname=dbname,
        user=redshift_user,
        password=redshift_pass,
        host=host,
        port=port
    ))
    conn.set_session(autocommit=autocommit)
    return conn

# %% [markdown]
# AUTOCOMMIT을 False로 지정해 주었다. 이럴 경우 직접 COMMIT을 해 주어야 테이블에 완전하게 반영된다.

# %%
conn = get_Redshift_connection(False) 
cur = conn.cursor()

# %%
cur.execute("SELECT * FROM ADHOC.SONGJIHYE_NAME_GENDER;")
res = cur.fetchall()
for r in res:
  print(r)
# Out:
# ('Ben', 'Male')
# ('Maddie', 'Female')

# %%
cur.execute("DELETE FROM ADHOC.SONGJIHYE_NAME_GENDER;")

# %%
cur.execute("SELECT * FROM ADHOC.SONGJIHYE_NAME_GENDER;")
res = cur.fetchall()
for r in res:
  print(r)

# %%
cur.execute("INSERT INTO ADHOC.SONGJIHYE_NAME_GENDER VALUES('Keeyong', 'Male');")

# %%
cur.execute("COMMIT;")

# %%
conn.close()

# %% [markdown]
# INSERT SQL을 AUTOCOMMIT=FALSE로 실행했을 때 psycopg2로 컨트롤하는 방법
# - 이 방법이 더 python에 맞는 방법이다.

# %%
conn = get_Redshift_connection(False) 
cur = conn.cursor()

# %% [markdown]
# 이 방법을 사용하면 만약 예외 처리에 오류로 걸리지 않는다면 바로 넣은 값이 COMMIT 되게 된다. 그렇지 않고 오류가 발생했다면 ROLLBACK이 되도록 .rollback() 함수로 처리해 주었다.

# %%
try:
  cur.execute("DELETE FROM ADHOC.SONGJIHYE_NAME_GENDER;") 
  cur.execute("INSERT INTO ADHOC.SONGJIHYE_NAME_GENDER VALUES ('Claire', 'Female');")
  conn.commit()
except (Exception, psycopg2.DatabaseError) as error:
  print(error)
  conn.rollback()
finally :
  conn.close()

# %%
conn.close()

# %% [markdown]
# 만약 AUTOCOMMIT=TRUE로 실행했다면 따로 COMMIT 함수를 사용하지 않아도 SQL이 실행될 때마다 모든 경우가 COMMIT 처리된다.
# 다만 BEGIN; END; 사이에 존재한다면 하나의 쿼리라도 SQL 실행 과정에서 오류가 발생했을 경우 BEGIN 이전의 단계로 ROLLBACK 된다.

# %%
conn = get_Redshift_connection(True)
cur = conn.cursor()

# %%
cur.execute("SELECT * FROM ADHOC.SONGJIHYE_NAME_GENDER;")
res = cur.fetchall()
for r in res:
  print(r)
# Out:
# ('Claire', 'Female')

# %%
cur.execute("BEGIN;")
cur.execute("DELETE FROM ADHOC.SONGJIHYE_NAME_GENDER;")
cur.execute("INSERT INTO ADHOC.SONGJIHYE_NAME_GENDER VALUES ('Benjamin', 'Male');")
cur.execute("END;")

# %%
cur.execute("SELECT * FROM ADHOC.SONGJIHYE_NAME_GENDER;")
res = cur.fetchall()
for r in res:
  print(r)
# Out:
# ('Benjamin', 'Male')

# %% [markdown]
# 없는 테이블을 호출하여 데이터를 INSERT 하려고 할 경우 오류가 발생한다. 이때 바로 위에서 모든 데이터를 지웠다고 하더라도 BEGIN 이전의 상태인 Benjamin이 조회되어야 한다.

# %%
cur.execute("BEGIN;")
cur.execute("DELETE FROM adhoc.SONGJIHYE_NAME_GENDER;")
cur.execute("INSERT INTO adhoc.SONGJIHYE_NAME_GENDER2 VALUES ('Andrew', 'Male');")
cur.execute("END;")
# Out:
# ---------------------------------------------------------------------------
# UndefinedTable                            Traceback (most recent call last)
# <ipython-input-41-adc86aac48b8> in <cell line: 3>()
#       1 cur.execute("BEGIN;")
#       2 cur.execute("DELETE FROM adhoc.SONGJIHYE_NAME_GENDER;")
# ----> 3 cur.execute("INSERT INTO adhoc.SONGJIHYE_NAME_GENDER2 VALUES ('Andrew', 'Male');")
#       4 cur.execute("END;")
#
# UndefinedTable: relation "adhoc.songjihye_name_gender2" does not exist

# %%
cur.execute("SELECT * FROM ADHOC.SONGJIHYE_NAME_GENDER;")
res = cur.fetchall()
for r in res:
  print(r)
# Out:
# ('Benjamin', 'Male')

# %% [markdown]
# ## 기타 SQL 고급 문법

# %% [markdown]
# UNION과 UNION ALL
# - UNION은 중복 제거
# - UNION ALL은 중복을 포함하여 모든 데이터를 출력함

# %%
# %%sql
#
# SELECT 'keeyong' AS first_name
#      , 'han' AS last_name
# UNION
# SELECT 'elon', 'musk'
# UNION
# SELECT 'keeyong', 'han'
# Out:
#  * postgresql://guest:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 2 rows affected.
# [('elon', 'musk'), ('keeyong', 'han')]

# %%
# %%sql
#
# SELECT 'keeyong' AS first_name
#      , 'han' AS last_name
# UNION ALL
# SELECT 'elon', 'musk'
# UNION ALL
# SELECT 'keeyong', 'han'
# Out:
#  * postgresql://guest:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 3 rows affected.
# [('keeyong', 'han'), ('elon', 'musk'), ('keeyong', 'han')]

# %% [markdown]
# LISTAGG

# %%
# %%sql
#
# SELECT A.USERID
#      , LISTAGG(A.CHANNEL,'->') WITHIN GROUP (ORDER BY B.TS) CHANNELS
#   FROM RAW_DATA.USER_SESSION_CHANNEL A
#   JOIN RAW_DATA.SESSION_TIMESTAMP B
#     ON A.SESSIONID = B.SESSIONID
# GROUP BY 1
# LIMIT 10;
# Out:
#  * postgresql://guest:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 10 rows affected.
# [(27, 'Youtube->Google->Naver->Facebook->Facebook->Google->Google->Facebook->Organic->Organic->Organic->Organic->Facebook->Naver->Naver->Organic->Google->In ... (1145 characters truncated) ... ->Facebook->Instagram->Google->Facebook->Naver->Organic->Instagram->Facebook->Instagram->Google->Facebook->Youtube->Organic->Naver->Google->Instagram'),
#  (29, 'Naver->Youtube->Google->Facebook->Naver->Google->Organic->Organic->Google->Organic->Instagram->Organic->Facebook->Google->Naver->Instagram->Naver->Yo ... (447 characters truncated) ... am->Naver->Facebook->Organic->Google->Instagram->Naver->Instagram->Instagram->Youtube->Facebook->Instagram->Organic->Youtube->Organic->Organic->Naver'),
# ...

# %% [markdown]
# LAG
# - WINDOW 함수로 목록에서 이전 값이나 다음 값을 보여 주고 싶을 때 사용하는 함수이다.
# - 예를 들어 어떤 사용자 세션에서 시간 순으로 봤을 때 앞 세션의 채널이 무엇인지 알고 싶다면?

# %%
# %%sql
#
# SELECT A.*
#      , B.TS
#      , LAG(CHANNEL, 1) OVER (PARTITION BY USERID ORDER BY TS) PREV_CHANNEL
#   FROM RAW_DATA.USER_SESSION_CHANNEL A
#   JOIN RAW_DATA.SESSION_TIMESTAMP B
#     ON A.SESSIONID = B.SESSIONID
#  ORDER BY A.USERID, B.TS
# LIMIT 100;
# Out:
#  * postgresql://guest:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 100 rows affected.
# [(27, 'a67c8c9a961b4182688768dd9ba015fe', 'Youtube', datetime.datetime(2019, 5, 1, 17, 3, 59, 957000), None),
#  (27, 'b04c387c8384ca083a71b8da516f65f6', 'Google', datetime.datetime(2019, 5, 2, 19, 21, 30, 280000), 'Youtube'),
#  (27, 'abebb7c39f4b5e46bbcfab2b565ef32b', 'Naver', datetime.datetime(2019, 5, 3, 20, 38, 40, 730000), 'Google'),
#  (27, 'ab49ef78e2877bfd2c2bfa738e459bf0', 'Facebook', datetime.datetime(2019, 5, 4, 21, 48, 7, 300000), 'Naver'),
#  (27, 'f740c8d9c193f16d8a07d3a8a751d13f', 'Facebook', datetime.datetime(2019, 5, 5, 18, 15, 30, 540000), 'Facebook'),
#  (27, 'ef452c63f81d0105dd4486f775adec81', 'Google', datetime.datetime(2019, 5, 6, 17, 49, 15, 437000), 'Facebook'),
#  (27, 'd7f426ccbc6db7e235c57958c21c5dfa', 'Google', datetime.datetime(2019, 5, 7, 20, 41, 25, 293000), 'Google'),
# ...

# %% [markdown]
# 반대로 다음 접속한 채널이 무엇인지 궁금하다면 ORDER BY 조건을 DESC 내림차순으로 바꿔 주면 된다.

# %%
# %%sql
#
# SELECT A.*
#      , B.TS
#      , LAG(CHANNEL, 1) OVER (PARTITION BY USERID ORDER BY TS DESC) NEXT_CHANNEL
#   FROM RAW_DATA.USER_SESSION_CHANNEL A
#   JOIN RAW_DATA.SESSION_TIMESTAMP B
#     ON A.SESSIONID = B.SESSIONID
#  ORDER BY A.USERID, B.TS
# LIMIT 100;
# Out:
#  * postgresql://guest:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 100 rows affected.
# [(27, 'a67c8c9a961b4182688768dd9ba015fe', 'Youtube', datetime.datetime(2019, 5, 1, 17, 3, 59, 957000), 'Google'),
#  (27, 'b04c387c8384ca083a71b8da516f65f6', 'Google', datetime.datetime(2019, 5, 2, 19, 21, 30, 280000), 'Naver'),
#  (27, 'abebb7c39f4b5e46bbcfab2b565ef32b', 'Naver', datetime.datetime(2019, 5, 3, 20, 38, 40, 730000), 'Facebook'),
#  (27, 'ab49ef78e2877bfd2c2bfa738e459bf0', 'Facebook', datetime.datetime(2019, 5, 4, 21, 48, 7, 300000), 'Facebook'),
#  (27, 'f740c8d9c193f16d8a07d3a8a751d13f', 'Facebook', datetime.datetime(2019, 5, 5, 18, 15, 30, 540000), 'Google'),
#  (27, 'ef452c63f81d0105dd4486f775adec81', 'Google', datetime.datetime(2019, 5, 6, 17, 49, 15, 437000), 'Google'),
#  (27, 'd7f426ccbc6db7e235c57958c21c5dfa', 'Google', datetime.datetime(2019, 5, 7, 20, 41, 25, 293000), 'Facebook'),
# ...

# %% [markdown]
# JSON Parsing 함수

# %%
# %%sql
#
# SELECT JSON_EXTRACT_PATH_TEXT('{"f2":{"f3": "1"},"f4":{"f5":"99","f6":"star"}}','f4', 'f6');
# Out:
#  * postgresql://guest:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 1 rows affected.
# [('star',)]
